# %%
# Validate ECT Summary Stats

import os 

dir_ECT = '/media/nas/GBIF_Downloads/Magnoliales/Himantandraceae/LM2/Data/Measurements/ECT'

# Create a list of all full file paths
file_paths = []
for root, dirs, files in os.walk(dir_ECT):
    for file in files:
        file_paths.append(os.path.join(root, file))

print(len(file_paths))
print(file_paths)
# Out:
# 216
# ...
